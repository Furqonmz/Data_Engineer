# %% [markdown]
# <a href="https://colab.research.google.com/github/Furqonmz/Data_Engineer/blob/main/Data_Engineer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 35
y = 56
z = x+y
print(z)
# Out:
# 91

# %%
a = 1
a = a + 1
print(a)
# Out:
# 2

# %%
text_contoh = 'abcdef'
type(text_contoh)
# Out:
# str

# %%
list_contoh = [1,2,3,4,5]
list_contoh_2 = ['a','b','c','d','e','f']
list_contoh_2[2]
# Out:
# 'c'

# %%
list_contoh = [1,2,3,4,5,6,10]
list_contoh.append('abc') #fungsi append untuk menambahkan 'abc'
print(list_contoh)
# Out:
# [1, 2, 3, 4, 5, 6, 10, 'abc']

# %%
list_contoh = [[1,2,3,4,5],'a','b',77]
list_contoh[0][1]
# Out:
# 2

# %%
set_contoh = set(['d','i','b','i','m','b','i','n','g'])
print(set_contoh)
# set_contoh[0]
# Out:
# {'i', 'g', 'n', 'b', 'd', 'm'}

# %%
daftar_harga = {'biru' : 10000, 'merah':12500, 'hijau':8500}
daftar_harga['hijau']
list(daftar_harga.keys())
# list(daftar_harga.values())
# Out:
# ['biru', 'merah', 'hijau']

# %%
daftar_harga = {
    'biru' : 10000,
    'merah':12500,
    'hijau':8500}

warna_belanjaan = ['hijau','hijau','biru','merah','merah','biru','hijau']
harga_list = [daftar_harga[x] for x in warna_belanjaan]
harga_list
total_harga = sum(harga_list)
total_harga
# Out:
# 70500

# %%
dictionary = {'Apple':['iphone 11', 'Airpods', 'Macbook Pro'],
              'Samsung': ['A53', 'A52 5G', 'Galaxy Buds'],
              'Sony':['Camera', 'Noise Cancelling Headphones', 'Xperia']}
dictionary['Apple'][2]
# Out:
# 'Macbook Pro'

# %%
1+2
2+3
3+4
# Out:
# 7

# %%
print(1+2)
print(2+3)
print(3+4)
# Out:
# 3
# 5
# 7

# %%
nama = 'Steven'
print(f'Nama peserta adalah {nama}, Peserta tersebut telah tercatat')
# Out:
# Nama peserta adalah Steven, Peserta tersebut telah tercatat

# %%
nilai_1 = 90
nilai_2 = 100
nilai_3 = 80
print(f'rata-rata nilai : {((nilai_1+nilai_2+nilai_3)/3)} poin')
# Out:
# rata-rata nilai : 90.0 poin

# %%
warna_belanjaan
# Out:
# ['hijau', 'hijau', 'biru', 'merah', 'merah', 'biru', 'hijau']

# %%
len(warna_belanjaan)
# Out:
# 7

# %%
def luas_keliling(panjang, lebar):
  luas = panjang * lebar
  keliling = 2* (panjang + lebar)
  return luas, keliling

# %%
luas_keliling(10,11)
# Out:
# (110, 42)

# %%
luas_keliling(10,11)[0]
# Out:
# 110

# %%
jawaban_l, jawaban_k = luas_keliling(7,4)
print(jawaban_l)
print(jawaban_k)
# Out:
# Luas persegi panjang 28
# Keliling persegi panjang 22
# 28
# 22

# %%
def luas_keliling(panjang, lebar):
  luas = panjang * lebar
  keliling = 2 * (panjang+lebar)

  print('Luas persegi panjang', luas)
  print('Keliling persegi panjang', keliling)

  return luas, keliling

# %%
jawaban_luas, jawaban_keliling = luas_keliling(9,4)
# Out:
# Luas persegi panjang 36
# Keliling persegi panjang 26

# %%
print(jawaban_luas)
# Out:
# 36

# %%
def luas_keliling(panjang, lebar):
  """
  Fungsi ini menerima dua input, yaitu panjang dan lebar.
  Jika Panjang lebih pendek daripada lebar, maka kedua nilai tersebut akan saling ditukar.
  Setelah itu, luas dan keliling persegi panjang akan dihitung.
  Pada akhirnya, nilai luas dan keliling akan di print, dan direturn, dengan urutan luas, keliling.
  """
  if panjang < lebar:
    lebar, panjang = panjang, lebar
    print('Waduh! Kok panjang lebih pendek daripada lebar, kita switch ya!')
  else:
    pass

  luas = panjang * lebar
  keliling = 2 * (panjang+lebar)

  print(f'Luas persegi panjang yang memiliki panjang {panjang} dan lebar {lebar} adalah {luas}')
  print(f'Keliling persegi panjang yang memiliki panjang {panjang} dan lebar {lebar} adalah {keliling}')

  return luas, keliling

# %%
luas_keliling(4,9)
# Out:
# Waduh! Kok panjang lebih pendek daripada lebar, kita switch ya!
# Luas persegi panjang yang memiliki panjang 9 dan lebar 4 adalah 36
# Keliling persegi panjang yang memiliki panjang 9 dan lebar 4 adalah 26
# (36, 26)

# %%
list_contoh.append(8)
list_contoh
# Out:
# [[1, 2, 3, 4, 5], 'a', 'b', 77, 8, 8]

# %%
himpunan_baru = {1,2,3,4,5}
himpunan_baru.add(8)
himpunan_baru
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
list_loop = ['Aldo','Budi','Cindy','Dilan','Ed Sheeran']

for x in list_loop:
  print('Nama Peserta:', x)
# Out:
# Nama Peserta: Aldo
# Nama Peserta: Budi
# Nama Peserta: Cindy
# Nama Peserta: Dilan
# Nama Peserta: Ed Sheeran

# %%
nama = 'ABC'

for u in range(10):
  print(nama)
# Out:
# ABC
# ABC
# ABC
# ABC
# ABC
# ABC
# ABC
# ABC
# ABC
# ABC

# %%
nilai = 80

if nilai > 70:
  print('lulus')
else:
  print('Tidak Lulus')
# Out:
# lulus

# %%
2+4 > 9
# Out:
# False

# %%
teks = 'dibimbing'
teks[1:4]
# Out:
# 'ibi'

# %%
teks[-5:-1]
# Out:
# 'mbin'

# %%
text = 'This is a sentence'
text.split(' ')
# Out:
# ['This', 'is', 'a', 'sentence']

# %%
text_3 = 'Coding-dengan-python'
text_3.split('-')
# Out:
# ['Coding', 'dengan', 'python']
